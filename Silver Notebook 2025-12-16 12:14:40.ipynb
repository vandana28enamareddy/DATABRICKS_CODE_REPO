-- %%
%sql
create database Silver

-- %%
use Silver

-- %%
%sql
create table Silver.Agent(agent_id int,agent_name string,agent_email string,agent_phone long,branch_id int,create_timestamp string)

-- %%
%sql
describe Silver.Agent

-- %%
%sql
create table Silver.Branch(branch_id int,branch_country string,branch_city string)

-- %%
describe Silver.Branch

-- %%
%sql
create table Silver.Claim(claim_id int, policy_id int, date_of_claim string, claim_amount int, claim_status string, LastUpdatedTimeStamp string)

-- %%
describe Silver.Claim

-- %%
%sql
create table Silver.Policy(corrupt_record string,coverage_amount long,customer_id long,end_date string,policy_id long, policy_type string, premium long, start_date string)

-- %%
describe Silver.Policy

-- %%
%sql
create table Silver.Customer( customer_id int,first_name string,last_name string,email string,phone long,country string,city string,registration_date timestamp,date_of_birth timestamp,gender string )

-- %%
describe Silver.Customer
